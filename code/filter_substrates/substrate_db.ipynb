# %% [markdown]
# The goal of this script is to get all the unique substrates from a file and then try to filter out co-factors and other co-substrates.<br/><br/>Copyright (C) 2017  Martin Engqvist Lab<br/>This program is free software: you can redistribute it and/or modify<br/>it under the terms of the GNU General Public License as published by<br/>the Free Software Foundation, either version 3 of the License, or<br/>(at your option) any later version.<br/>This program is distributed in the hope that it will be useful,<br/>but WITHOUT ANY WARRANTY; without even the implied warranty of<br/>MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the<br/>GNU General Public License for more details.<br/>You should have received a copy of the GNU General Public License<br/>along with this program.  If not, see <http://www.gnu.org/licenses/>.

# %%
import os
from dotenv import load_dotenv, find_dotenv
from os.path import join, dirname, basename, exists, isdir

### Load environmental variables from the project root directory ###
# find .env automagically by walking up directories until it's found
dotenv_path = find_dotenv()

# load up the entries as environment variables
load_dotenv(dotenv_path)

# now you can get the variables using their names

# Check whether a network drive has been specified
DATABASE = os.environ.get("NETWORK_URL")
if DATABASE == 'None':
    pass
else:
    pass
    #mount network drive here

# set up directory paths
CURRENT_DIR = os.getcwd()
PROJ = dirname(dotenv_path) # project root directory

DATA = join(PROJ, 'data') #data directory
RAW_EXTERNAL = join(DATA, 'raw_external') # external data raw directory
RAW_INTERNAL = join(DATA, 'raw_internal') # internal data raw directory
INTERMEDIATE = join(DATA, 'intermediate') # intermediate data directory
FINAL = join(DATA, 'final') # final data directory

RESULTS = join(PROJ, 'results') # output directory
FIGURES = join(RESULTS, 'figures') # figure output directory
PICTURES = join(RESULTS, 'pictures') # picture output directory


# make folders specific for certain data
folder_name = 'brenda_data_2019_1'
if folder_name != '':
    #make folders if they don't exist
    if not exists(join(RAW_EXTERNAL, folder_name)):
        os.makedirs(join(RAW_EXTERNAL, folder_name))

    if not exists(join(INTERMEDIATE, folder_name)):
        os.makedirs(join(INTERMEDIATE, folder_name))

    if not exists(join(FINAL, folder_name)):
        os.makedirs(join(FINAL, folder_name))

print('Standard variables loaded, you are good to go!')
# Out:
# Standard variables loaded, you are good to go!

# %% [markdown]
# ## Here I want to develop a way to re-use the substrate to molecule conversion
# The reaseon is that cirpy takes a long time to reference the datbase. I therefore want to locally store the results.

# %% [markdown]
# First we load up the substrates from BRENDA

# %%
import json
import re

filepath = join(FINAL, 'brenda_data_2019_1', 'natural_substrates_filtered.json')
with open(filepath, 'r') as f:
    filtered_subst_data = json.loads(f.read())
    

    
def remove_dl(substrate):
    '''
    Remove D-, L-, DL- and similar from the beginning of substrates
    '''
    substrate = substrate.lower()
    return re.sub('^d-|^l-|^dl-|^\(r\)-|^\(s\)-', '', substrate)
    

def get_all_ec():
    '''
    Get a list of all ec numbers
    '''
    return filtered_subst_data.keys()

    
def get_substrates(ec):
    '''
    Obtain a list of all the natural substrates for an ec number
    '''
    substrate_list = filtered_subst_data[ec]['first_substrate']
    return sorted(list(set([remove_dl(s) for s in substrate_list])))


get_substrates('1.1.3.15')
# Out:
# ['2 -hydroxyisocaproate',
#  '2-hydroxy-4-methylthiobutanoic acid',
#  '2-hydroxybutyrate',
#  '2-hydroxycaproate',
#  '2-hydroxycaprylate',
#  '2-hydroxyisocaproate',
#  '2-hydroxyisovalerate',
#  '2-hydroxyoctanoate',
#  '2-hydroxypalmitate',
#  '2-hydroxyvalerate',
#  'alanine',
#  'an (s)-2-hydroxy carboxylate',
#  'glycerate',
#  'glycolate',
#  'glyoxylate',
#  'glyoxylate thiohemiacetals',
#  'homoserine',
#  'isoleucine',
#  'lactate',
#  'leucine',
#  'lysine',
#  'mandelate',
#  'methionine',
#  'phenylalanine',
#  'thiol-glyoxylate adducts',
#  'tryptophan',
#  'tyrosine',
#  'valine']

# %% [markdown]
# Now we want to use cirpy to get teh molecule for each of these. BUT, first we want to check wether we have a cached file. I will be loading up the cached data and potentially adding to it. So to keep the old backups safe I want to make a new backup each day that the script is run.

# %%
import datetime


currentDT = datetime.datetime.now()
cached_file_dir = join(INTERMEDIATE, 'brenda_data_2019_1')
filename = 'substrate_cache.json'
date = '%s-%s-%s' % (currentDT.year, str(currentDT.month).rjust(2, '0'), str(currentDT.day).rjust(2, '0')) # YY-MM-DD


def todays_filename():
    '''
    Get the filename of todays file.
    '''
    return join(cached_file_dir, '%s_%s' % (date, filename))


def most_recent_filename():
    '''
    Return the filepath of the most recent file.
    '''
    # first make a list of all available files
    file_data = {}
    for fi in os.listdir(cached_file_dir):
        if fi.endswith(filename):
            year, month, day = fi.replace(filename, '').split('-')
            
            if file_data.get(year) is None:
                file_data[year] = {}
                
            if file_data[year].get(month) is None:
                file_data[year][month] = {}
                
            file_data[year][month][day] = join(cached_file_dir, fi)
    
    # if there is no file
    if file_data == {}:
        return None
    
    max_year = max(file_data.keys())
    max_month = max(file_data[max_year].keys())
    max_day = max(file_data[max_year][max_month].keys())
    
    return file_data[max_year][max_month][max_day]
            

def open_file(filepath):
    '''
    Open up the json file and return data structure
    '''
    with open(filepath, 'r') as f:
        data = json.loads(f.read())
    return data


def save_data(data):
    '''
    Save data to todays file.
    '''
    filepath = todays_filename()
    with open(filepath, 'w') as f:
        f.write(json.dumps(data))

    
def load_data():
    '''
    Load up existing substrate to smile data
    '''
    # if a file from today exists open it up
    filepath = todays_filename()
    if exists(filepath):
        return open_file(filepath)
    
    # if no file exists from today then make a copy of the most recent file
    else:
        old_filepath = most_recent_filename()
        
        if old_filepath is None:
            data = {}
        
        else:
            data = open_file(old_filepath) # get most recent data

        save_data(data) # save into todays filename
        return data

data = load_data()
data
# Out:
# {'(-)-(s)-limonene': 'CC(=C)[C@H]1CCC(=CC1)C',
#  '1,2-linked glucuronic acid of non-reducing xylose-oligosaccahrides': None,
#  '(3e)-3-[(4s)-4-hydroxycyclohex-2-en-1-yl]-2-oxopropanoate': None,
#  '10-deoxysarpagine': 'C\\C=C/1CN2[C@H]3Cc4c([nH]c5ccccc45)[C@@H]2C[C@H]1C3CO',
#  'alpha-d-xyl-(1-&gt;6)-beta-d-glc-(1-&gt;4)-[alpha-d-xyl-(1-&gt;6)]-beta-d-glc-(1-&gt;4)-[alpha-d-xyl-(1-&gt;6)]-beta-d-glc-(1-&gt;4)-d-glc': None,
#  '(2-pyrrolyl)cysteine': 'OC(=O)[C@H](CS)Nc1[nH]ccc1',
#  '(3-hydroxy-phenylalkanoic acid)n': None,
#  '2-chloro-1-phenylethanol': 'OC(CCl)c1ccccc1',
#  'neuropeptides': None,
#  'ompx': None,
#  'histone h3 n6-dimethyl-l-lysine4': None,
#  'damaged psii d1 protein': None,
#  'coronavirus polyprotein': None,
#  'beta-d-galactosyl-(1-&gt;4)-l-rhamnose': None,
#  '22-cholesten-3beta-ol': 'CC(C)CC=C[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CCC4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'gag-pol polyprotein': None,
#  'cobalt-sirohydrochlorin': None,
#  'gum arabic': None,
#  'n,n-dimethyltryptamine': 'CN(C)CCc1c[nH]c2ccccc12',
#  'cholesta-5,24-dien-3beta-ol': 'C[C@H](CCC=C(C)C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'glyceraldehyde': 'OCC(O)C=O',
#  'sn-glycero-3-phospho-1-inositol': 'OCC(O)CO[P](O)(=O)OC1[C@H](O)[C@H](O)C(O)[C@H](O)[C@H]1O',
#  'ompa protein': None,
#  'protein cox2': None,
#  'pyrogallate': None,
#  "nucleoside 5'-diphosphate": None,
#  'all-trans retinol': 'CC(=C\\CO)/C=C/C=C(C)/C=C/C1=C(C)CCCC1(C)C',
#  "alpha-ribazole 5'-phosphate": 'Cc1cc2ncn([C@H]3O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@H]3O)c2cc1C',
#  '3beta-chlorocholest-5-ene': 'CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H](Cl)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'alpha-chitin': None,
#  'cmp-alpha-n-acetylneuraminate': None,
#  'pro-mcasp-7': None,
#  'tdp-3,4-didehydro-2,6-dideoxy-alpha-d-glucose': None,
#  '4-acetylpyridine': 'CC(=O)c1ccncc1',
#  'orosomucoid': None,
#  'selenite': '[O-][Se]([O-])=O',
#  'daunorubicin': 'COc1cccc2C(=O)c3c(O)c4C[C@](O)(C[C@H](O[C@H]5C[C@H](N)[C@H](O)[C@H](C)O5)c4c(O)c3C(=O)c12)C(C)=O',
#  '5-dehydroquinate': 'OC1CC(O)(CC(=O)C1O)C(O)=O',
#  'plugin glutamine': None,
#  '2-dehydro-3-deoxy-6-phospho-d-gluconate': 'O[C@H](CO[P](O)(O)=O)[C@@H](O)CC(=O)C([O-])=O',
#  '5-androstene-3,17-dione': 'C[C@]12CC[C@H]3[C@@H](CC=C4CC(=O)CC[C@]34C)[C@@H]1CCC2=O',
#  '3-o-alpha-d-glucopyranosyl-d-glucose': 'OC[C@@H](O)[C@@H](O)[C@H](O[C@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O)[C@@H](O)C=O',
#  '2-[5-amino-1-(5-phospho-d-ribosyl)imidazole-4-carboxamido]succinate': 'Nc1n(cnc1C(=O)NC(CC([O-])=O)C([O-])=O)C2O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@H]2O',
#  'sidekick-1': None,
#  'oyster glycogen': None,
#  'androst-4-ene-3,17-dione': 'C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@]34C)[C@@H]1CCC2=O',
#  'octadecanoyl-coa': 'CCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  'ribosomal s2 protein': None,
#  'oxidized rubredoxin': None,
#  '(e)-2-(acetamidomethylene)succinate': 'CC(=O)N\\C=C(CC([O-])=O)\\C([O-])=O',
#  '5-phosphoadenosine 3-phosphosulfate': 'Nc1ncnc2n(cnc12)C3OC(CO[P](O)(=O)O[S](O)(=O)=O)C(O[P](O)(O)=O)C3O',
#  '3-methylcrotonyl-coa': 'CC(C)=CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  '5-methylthioribulose 1-phosphate': 'CC(O)[C@@H](O)[C@@H](O)C(=S)CO[P](O)(O)=O',
#  '1-(4-chlorophenyl)ethanone': 'CC(=O)c1ccc(Cl)cc1',
#  '1-aminocyclopropane-1-carboxylate': 'NC1(CC1)C([O-])=O',
#  '(e/z)-isocapronaldoxime': None,
#  '3,4-dihydroxyphenylacetaldehyde': 'Oc1ccc(CC=O)cc1O',
#  'n-formyl-l-met-leu-phe': None,
#  'n2-succinyl-l-ornithine': 'NCCCC(NC(=O)CCC(O)=O)C(O)=O',
#  'mouse pro-growth hormone-releasing hormone': None,
#  'gonadotrophin-releasing hormone': None,
#  '2-oxo-3-methylbutanoate': 'CC(C)C(=O)C([O-])=O',
#  'protein ndufs3': None,
#  'protein gurken': None,
#  'glcman9glcnac': None,
#  'hyaluronan': None,
#  '4-hydroxybenzyl alcohol': 'OCc1ccc(O)cc1',
#  'flab2': None,
#  '5beta-androstan-3alpha-ol-17-one': 'C[C@]12CC[C@@H](O)C[C@H]1CC[C@@H]3[C@@H]2CC[C@@]4(C)[C@H]3CCC4=O',
#  'lamp1': None,
#  "5'-dcmp": None,
#  'glc2man9glcnac2 (g2m9)-protein': None,
#  '3-(5-oxo-4,5-dihydro-3h-imidazol-4-yl)propanoate': '[O-]C(=O)CCC1NC=NC1=O',
#  'tetrahydrocolumbamine': 'COc1cc2CCN3Cc4c(CC3c2cc1O)ccc(OC)c4OC',
#  '3-chloropropionate': '[O-]C(=O)CCCl',
#  'tissue growth factor beta1': None,
#  'phosphorylated-erbb-2': None,
#  '(+)-(s)-allyl-l-cysteine sulfoxide': None,
#  'pentane-2,4-dione': 'CC(=O)CC(C)=O',
#  'zeinoxanthin': 'CC(=C\\C=C\\C=C(C)\\C=C\\C=C(C)\\C=C\\C1=C(C)C[C@@H](O)CC1(C)C)/C=C/C=C(C)/C=C/[C@H]2C(=CCCC2(C)C)C',
#  '6,6-kestotetraose': None,
#  'nipi protein': None,
#  'fructose 1-phosphate': 'OC[C@@H](O)[C@@H](O)[C@H](O)C(=O)CO[P](O)(O)=O',
#  'geranyl-diphosphate': 'CC(C)=CCCC(/C)=C/CO[P]([O-])(=O)O[P]([O-])([O-])=O',
#  '4,5-dihydroxyphthalate': 'Oc1cc(C([O-])=O)c(cc1O)C([O-])=O',
#  'poly-sumo-2': None,
#  'fibronectin': None,
#  'hydrazine': 'NN',
#  'trna uridine55': None,
#  'dimethylated histone 3 lysine 9': None,
#  '(e)-1-(glutathion-s-yl)-n-hydroxy-2-(1h-indol-3-yl)ethan-1-imine': None,
#  'acetohexamide': 'CC(=O)c1ccc(cc1)[S](=O)(=O)NC(=O)NC2CCCCC2',
#  'enamelin': None,
#  'phenacetin': 'CCOc1ccc(NC(C)=O)cc1',
#  '13-deoxydaunorubicin': 'CC[C@@]1(O)C[C@H](O[C@H]2C[C@H](N)[C@H](O)[C@H](C)O2)c3c(O)c4C(=O)c5c(OC)cccc5C(=O)c4c(O)c3C1',
#  "guanosine 3'-diphosphate 5'-diphosphate": None,
#  '1,4-alpha-d-glucooligosaccharide': None,
#  'galactocerebroside': None,
#  'thiobenzamide': 'NC(=S)c1ccccc1',
#  'dihydrokaempferol': 'OC1C(Oc2cc(O)cc(O)c2C1=O)c3ccc(O)cc3',
#  'mitogen-activated protein kinase kinase 7': None,
#  '2-hydroxy-2-methyl-3-oxobutanoate': 'CC(=O)C(C)(O)C([O-])=O',
#  'man6-glycopeptide': None,
#  'swedish mutation of amyloid precursor protein': None,
#  '7-ethyl-10[4-(1-piperidino)-1-piperdino]carbonyloxy-camptothecin': None,
#  'n2-(d-1,3-dicarboxypropyl)-l-arginine': 'NC(N)=NCCCC(NC(CCC(O)=O)C(O)=O)C(O)=O',
#  'dtdp-3-dehydro-4,6-dideoxy-alpha-d-glucopyranose': None,
#  'quercetin': 'Oc1cc(O)c2C(=O)C(=C(Oc2c1)c3ccc(O)c(O)c3)O',
#  'proform mannan-binding lectin-associated serine protease 1': None,
#  'cheb': None,
#  'procollagen i': None,
#  'dolichyl phosphate d-mannose': 'CC/C(C)=C/CCCC(C)CCO[P](O)(=O)OC1OC(CO)C(O)C(O)C1O',
#  '2,4,5,6-tetrachloroisophthalonitrile': 'Clc1c(Cl)c(C#N)c(Cl)c(C#N)c1Cl',
#  '4-hydroxyphenylglycine': 'OC(=O)CNc1ccc(O)cc1',
#  'val': 'CC(C)C(N)C(O)=O',
#  'glutathione-s-transferase': None,
#  'sirna': None,
#  'dna-1-methyladenine': None,
#  '11beta,20alpha-dihydroxypregn-4-ene-3-one': None,
#  'corn endosperm xylan': None,
#  'hexadecanoyl-coa': 'CCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  'ssdna-dsdna': None,
#  'ala-d-glu': None,
#  'butanone': 'CCC(C)=O',
#  'angiotensin i': 'CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O)[C@@H](NC(=O)[C@H](CCCN=C(N)N)NC(=O)[C@@H](N)CC(O)=O)C(C)C)C(=O)N[C@@H](Cc2[nH]cnc2)C(=O)N3CCC[C@H]3C(=O)N[C@@H](Cc4ccccc4)C(=O)N[C@@H](Cc5[nH]cnc5)C(=O)N[C@@H](CC(C)C)C(O)=O',
#  '1,2,3-trichloropropane': 'ClCC(Cl)CCl',
#  'factor viii': None,
#  '(8z,11z,14z,17z)-icosa-8,11,14,17-tetraenoyl-[glycerolipid]': None,
#  'cdp': 'NC1=NC(=O)N(C=C1)C2OC(CO[P](O)(=O)O[P](O)(O)=O)C(O)C2O',
#  '[atp-citrate lyase]-n-phospho-l-histidine': None,
#  'cytosolic protein apaf-1': None,
#  'mitogen-activated protein kinase kinase 1': None,
#  'heparosan n-sulfate d-glucuronate': None,
#  '1,3,7-trimethylxanthine': 'Cn1cnc2N(C)C(=O)N(C)C(=O)c12',
#  'alpha-d-man-(1-2)-alpha-d-man-(1-2)-alpha-d-man-(1-3)-[alpha-d-man-(1-2)-alpha-d-man-(1-3)-[alpha-d-man-(1-2)-alpha-d-man-(1-6)]-alpha-d-man-(1-6)]-beta-d-man-(1-4)-beta-d-glcnac': None,
#  'proteins': None,
#  'lutein': 'CC(=C\\C=C\\C=C(C)\\C=C\\C=C(C)\\C=C\\C1=C(C)C[C@@H](O)CC1(C)C)/C=C/C=C(C)/C=C/[C@H]2C(=C[C@H](O)CC2(C)C)C',
#  'ac-yssvsrkll-7-amido-4-methylcoumarin': None,
#  'vamp 2': None,
#  '2,3-dihydroxyindole': 'Oc1[nH]c2ccccc2c1O',
#  'man-glycopeptide': None,
#  'androgen receptor': None,
#  'wheat graminan': None,
#  'ntp': 'CO[C@H]1O[C@H](CO[S](O)(=O)=O)[C@@H](O[C@@H]2O[C@H]([C@@H](O[C@H]3O[C@H](CO[S](O)(=O)=O)[C@@H](O[C@@H]4O[C@@H]([C@@H](O[C@H]5O[C@H](CO[S](O)(=O)=O)[C@@H](OC)[C@H](OC)[C@H]5O[S](O)(=O)=O)[C@H](OC)[C@H]4OC)C(O)=O)[C@H](O[S](O)(=O)=O)[C@H]3O[S](O)(=O)=O)[C@H](OC)[C@H]2O[S](O)(=O)=O)C(O)=O)[C@H](O[S](O)(=O)=O)[C@H]1O[S](O)(=O)=O',
#  'glycolate': 'OCC([O-])=O',
#  'chlorophyll a': '[Mg++].CCc1c(C)c2cc3[n-]c(cc4nc([C@@H](CCC(=O)OC\\C=C(C)\\CCCC(C)CCCC(C)CCCC(C)C)[C@@H]4C)c5C(C(=O)OC)C(=O)c6c(C)c([n-]c56)cc1n2)c(C)c3C=C',
#  'small ubiquitin-related modifier-mdm2': None,
#  '4-amino-5-aminomethyl-2-methyl-pyrimidine': 'Cc1ncc(CN)c(N)n1',
#  'tryptamine': 'NCCc1c[nH]c2ccccc12',
#  's-bis-lactoyltrypanothione': None,
#  'atropine': 'CN1C2CCC1CC(C2)OC(=O)C(CO)c3ccccc3',
#  'sinapyl alcohol': 'COc1cc(/C=C/CO)cc(OC)c1O',
#  '(4e,6e)-2-methyl-3-oxoocta-4,6-dienoyl-s-acp': None,
#  'plant cell wall': None,
#  '2,3-dichloropropionate': '[O-]C(=O)C(Cl)CCl',
#  'thyrotropin': None,
#  'alanyl-trnaala': None,
#  'complement component c3(nh3)': None,
#  'stearoyl-[acyl-carrier protein]': None,
#  'phospho-tak1': None,
#  'pro-b-type natriuretic peptide': None,
#  'rhamnulose 1-phosphate': 'C[C@H](O)[C@@H](O)[C@H](O)C(=O)CO[P](O)(O)=O',
#  'dna containing 6-o-methylguanine': None,
#  'qh2': 'COc1c(O)c(C)c(C\\C=C(C)\\CCC=C(C)C)c(O)c1OC',
#  'protein l-arginine': None,
#  'cystine': 'N[C@@H](CSSC[C@H](N)C(O)=O)C(O)=O',
#  'histamine': 'NCCc1c[nH]cn1',
#  'mammalian sterile 20-like kinase 1': None,
#  'carnitinyl-coa': None,
#  '1alpha,25-dihydroxyvitamin d3': 'C[C@H](CCCC(C)(C)O)[C@H]1CC[C@H]2\\C(CCC[C@]12C)=C\\C=C3\\C[C@@H](O)C[C@H](O)C3=C',
#  'tyrosine aminotransferase': None,
#  'ent-kaur-16-ene-19-al': None,
#  'galactitol-1-phosphate': 'OC[C@@H](O)[C@H](O)[C@H](O)[C@@H](O)CO[P](O)(O)=O',
#  'valine': 'CC(C)[C@H](N)C(O)=O',
#  'ccn2 protein': None,
#  'proform platelet-derived growth factor a': None,
#  'methyl-coenzyme m': 'CSCC[S](O)(=O)=O',
#  '6,7-dehydrohyoscyamine': None,
#  'a [methyl-co(iii) methanol-specific corrinoid protein]': None,
#  'phosphatidylinositol-dependent kinase-1': None,
#  'glyceraldehyde-3-phosphate': 'OC(CO[P](O)(O)=O)C=O',
#  'phospho-l-tyrosine': 'N[C@@H](Cc1ccc(O[P](O)(O)=O)cc1)C(O)=O',
#  '2-dehydro-3-deoxy-d-galactonate': 'OC[C@@H](O)[C@H](O)CC(=O)C([O-])=O',
#  "nucleoside 5'-triphosphate": None,
#  'insulin-like growth factor-ii': None,
#  'larchwood arabinogalactan': None,
#  'hexitol phosphate': None,
#  'double-stranded rna': None,
#  '4-hydroxy-l-glutamate': 'N[C@@H](CC(O)C([O-])=O)C([O-])=O',
#  '3-epi-1alpha,23,25-trihydroxy-24-oxo-vitamin d3': None,
#  'italian rye gras cell walls': None,
#  '[histidine kinase arcb]-n-phospho-l-histidine': None,
#  'cyclo(l-leu-l-phe)': None,
#  'coproporphyrinogen-iv': None,
#  '2-(4-chlorophenyl)-5-(2-furyl)-4-oxazoleacetic acid': 'OC(=O)Cc1nc(oc1c2occc2)c3ccc(Cl)cc3',
#  'histamine h2 receptor': None,
#  '(-)-3,5-cyclohexadiene-1,2-diol-1-carboxylic acid': None,
#  'beta-tubulin': None,
#  'k-ras(farnesyl)vim': None,
#  'beta-d-glucopyranosyl abscisate': None,
#  'hypoxia-inducible factor 1 alpha-l-proline': None,
#  '7-dehydrodesmosterol': 'C[C@H](CCC=C(C)C)[C@H]1CC[C@H]2C3=CC=C4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'hydroxymalonate': 'OC(C([O-])=O)C([O-])=O',
#  'ureidoacrylate peracid': None,
#  'propionohydrazide': 'CCC(=O)NN',
#  '1,2-dichloroethane': 'ClCCCl',
#  'allyl isothiocyanate': 'C=CCN=C=S',
#  '3-hydroxy-4-trimethylaminobutyrate': None,
#  '1,2-hexadecandiol': 'CCCCCCCCCCCCCCC(O)CO',
#  'dynorphin 1-8': None,
#  'chcl3': 'ClC(Cl)Cl',
#  'collagen iii': None,
#  '9-cis,11-trans-linoleic acid': None,
#  'carboxypeptidase y': None,
#  'indole-3-acetyl-beta-1-d-glucoside': 'OC[C@H]1O[C@@H](OC(=O)Cc2c[nH]c3ccccc23)[C@H](O)[C@@H](O)[C@@H]1O',
#  'colanic acid': None,
#  'magnesium-protoporphyrin ix 13-monomethyl ester': '[Mg++].COC(=O)CCc1c(C)c2[n-]c1cc3nc(cc4[n-]c(cc5nc(c2)c(C=C)c5C)c(C=C)c4C)c(C)c3CCC(O)=O',
#  'poly(3-hydroxybutyrate)': 'CC(O)CC(O)=O',
#  'c18:0-ceramide': None,
#  '(3r)-3-hydroxymyristoyl-[acyl-carrier protein]': None,
#  "adenosine 5'-phosphosulfate": 'Nc1ncnc2n(cnc12)[C@@H]3O[C@H](CO[P](O)(=O)O[S](O)(=O)=O)[C@@H](O)[C@H]3O',
#  'allantoin': 'NC(=O)NC1NC(=O)NC1=O',
#  'ch2br-ch2cl': None,
#  'alpha-linoleoyl-[glycerolipid]': None,
#  'benzo[a]pyrene': 'c1ccc2c(c1)cc3ccc4cccc5ccc2c3c45',
#  '6-oxocineole': 'CC1(C)OC2(C)CCC1CC2=O',
#  '(12s)-hpete': None,
#  '17beta-estradiol': 'C[C@]12CC[C@H]3[C@@H](CCc4cc(O)ccc34)[C@@H]1CC[C@@H]2O',
#  '8-dimethylallylnaringenin': None,
#  '(3r)-acetoin': None,
#  '2-deoxy-d-ribosyl-base1': None,
#  'poly[(r)-3-hydroxybutanoate]n': None,
#  '2-iminoacetate': '[O-]C(=O)C=N',
#  'polyneuridine aldehyde': 'COC(=O)C1(C=O)[C@@H]2Cc3c([nH]c4ccccc34)[C@@H]5C[C@@H]1\\C(CN25)=C/C',
#  'sumo-pc2/cbx4 conjugate': None,
#  'digalactosyldiacylglycerol': None,
#  '3-amino-2-methylpropanoate': 'CC(CN)C([O-])=O',
#  'rifampicin': None,
#  'cis-dienelactone': None,
#  'taurocholic acid': 'C[C@H](CCC(=O)NCC[S](O)(=O)=O)[C@H]1CC[C@H]2[C@@H]3[C@H](O)C[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3C[C@H](O)[C@]12C',
#  'diacetyl-lysyl-trnalys': None,
#  'cysteinylglycine': 'N[C@@H](CS)C(=O)NCC(O)=O',
#  'desmoglein 2': None,
#  'colicin m': None,
#  'adamts13': None,
#  'c3 protein of complement system': None,
#  'epoxyeicosatrienoic acid': 'CCCCCCCCCCCCCC=CC=CC1=C(O1)C(O)=O',
#  'sphingomyelin': None,
#  'sulfogalactosylglycerolipid': None,
#  'dengue virus den4 polyprotein': None,
#  'dsrc protein disulfide': None,
#  'membrane-bound prostaglandin e2 synthase-2': None,
#  'nplp4 protein': None,
#  'dynorphin a1-8': None,
#  'n8-acetylspermidine': 'CC(=O)NCCCCNCCCN',
#  'n6-(2-isopentenyl)adenine': 'CC(C)=CCn1cnc(N)c2ncnc12',
#  'histone h3 n6,n6-dimethyl-l-lysine9': None,
#  'n-butanoyl-[acyl-carrier protein]': None,
#  'complement component c3b': None,
#  'udp-3-o-[(3r)-3-hydroxymyristoyl]-n-acetyl-alpha-d-glucosamine': None,
#  '1,16-hexadecandiol': 'OCCCCCCCCCCCCCCCCO',
#  '4-hydroxynonenal': 'CCCCCC(O)C=CC=O',
#  '2-hydroperoxyoctadecatrienoic acid': 'CCCCCCCCCCCC=CC=CC=C(OO)C(O)=O',
#  'sepiapterin': 'CC(O)C(=O)C1=NC2C(NC1)N=C(N)NC2=O',
#  'lamin b2': None,
#  '1-(3-bromophenyl)ethanol': 'CC(O)c1cccc(Br)c1',
#  'bentazon': 'CC(C)N1C(=O)c2ccccc2N[S]1(=O)=O',
#  'n-lauroyl-d-erythro-sphingosylphosphorylcholine': None,
#  'epsilon-(gamma-l-glutamyl)-l-lysine': 'N[C@@H](CCCC(N)C(=O)CC[C@H](N)C(O)=O)C(O)=O',
#  'beta-d-fucoside': 'C[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O',
#  'n-acetyl-lysine-histone h1': None,
#  '(e,e)-geranyllinalool': 'CC(C)=CCCC(/C)=C/C/C=C/C(C)(O)CCC=C(C)C',
#  'cationic channel subunit transient receptor potential channel 1': None,
#  '3-oxo-23,24-bisnorcholesta-1,4-dien-22-oyl-coa': None,
#  'nuclei': None,
#  'beta-d-glucans': None,
#  '4-fluorophenol': 'Oc1ccc(F)cc1',
#  'kallidin': 'NCCCCC(N)C(=O)NC(CCCN=C(N)N)C(=O)N1CCCC1C(=O)N2CCCC2C(=O)NCC(=O)NC(Cc3ccccc3)C(=O)NC(CO)C(=O)N4CCCC4C(=O)NC(Cc5ccccc5)C(=O)NC(CCCN=C(N)N)C(O)=O',
#  'p-coumaryl alcohol': 'OC\\C=C\\c1ccc(O)cc1',
#  'thyroliberin': 'NC(=O)[C@@H]1CCCN1C(=O)[C@H](Cc2[nH]cnc2)NC(=O)[C@@H]3CCC(=O)N3',
#  '[protein]-l-serine phosphate': None,
#  's-adenosyl-l-homocysteine': 'NC(CCSCC1OC(C(O)C1O)n2cnc3c(N)ncnc23)C(O)=O',
#  'cys-gly': 'N[C@@H](CS)C(=O)NCC(O)=O',
#  'n-acetylated beta-(1-&gt;6)-n-acetylglucosamine polymer': None,
#  'eukaryotic initiation factor eif4gi': None,
#  'cefoperazone': 'CCN1CCN(C(=O)N[C@@H](C(=O)N[C@H]2[C@H]3SCC(=C(N3C2=O)C(O)=O)CSc4nnnn4C)c5ccc(O)cc5)C(=O)C1=O',
#  'mesoporphyrinogen ix': None,
#  '6-hydroxyhexanoate': 'OCCCCCC([O-])=O',
#  'transmembrane glycoprotein': None,
#  '5-carboxyamino-1-(5-phospho-d-ribosyl)imidazole': 'O[C@H]1[C@@H](O)C(O[C@@H]1CO[P](O)(O)=O)n2cncc2NC(O)=O',
#  'cux1 transcription factor': None,
#  "cyclic 2',3'-amp": None,
#  'amyloid-beta protein 43': None,
#  'ribonucleic acid': None,
#  'omega-n-(l-arginino)succinate': None,
#  'tabersonine': 'CC[C@@]12CC(=C3Nc4ccccc4[C@@]35CCN(CC=C1)[C@@H]25)C(=O)OC',
#  'protein f0 subunit 6': None,
#  '(6e)-8-hydroxygeraniol': None,
#  'aldehyde': 'CC=O',
#  'rs toxin': None,
#  'cyclohexanol': 'OC1CCCCC1',
#  'mannitol 1-phosphate': 'OC[C@@H](O)[C@@H](O)[C@H](O)[C@H](O)CO[P](O)(O)=O',
#  'tissue factor pathway inhibitor': None,
#  '2,3-dihydroxy-3-methylbutanoate': 'CC(C)(O)C(O)C([O-])=O',
#  'trna precursor': None,
#  'adhesin jesebl': None,
#  '3-epi-1alpha,24,25-trihydroxyvitamin d3': None,
#  'glucosone': 'OC[C@@H](O)[C@@H](O)[C@H](O)C(=O)C=O',
#  '5-methylcytosine in single-stranded dna': None,
#  '(2r/3r)-dihydroquercetin': None,
#  'insulin-like growth factor i': None,
#  'precorrin-3a': None,
#  "3beta-hydroxy-8'-apo-beta-carotenal": None,
#  '6-(l-erythro-1,2-dihydroxypropyl 3-triphosphate)-7,8-dihydropterin': 'NC1=NC(=O)C2=C(NCC(=N2)[C@H](O)[C@H](O)CO[P](O)(=O)O[P](O)(=O)O[P](O)(O)=O)N1',
#  'deoxycytosine in single-stranded viral dna': None,
#  'melanin': 'CC1=C2NC=C3C4=C5C(=C(C)C(=O)C4=O)NC=C5C(=C23)C(=O)C1=O',
#  'ftsl protein': None,
#  'a 1-linoleoyl 2-acyl-sn-glycerol 3-phosphate': None,
#  'dihydromacarpine': 'COc1cc2c(N(C)Cc3c4OCOc4cc(OC)c23)c5cc6OCOc6cc15',
#  'prenyl diphosphate': 'CC(C)=CCO[P]([O-])(=O)O[P]([O-])([O-])=O',
#  'glial fibrillary acidic protein': None,
#  'precorrin-3': None,
#  'o-acetyl-adp-ribose': None,
#  'pro-renin receptor': None,
#  'geranylgeraniol': 'CC(C)=CCCC(/C)=C/CCC(C)=CCC\\C(C)=C\\CO',
#  '3aminopropanal+ nad+': None,
#  '5-aminopentanamide': 'NCCCCC(N)=O',
#  '11alpha-hydroxy-pregn-4-ene-3,20-dione': 'CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3[C@H](O)C[C@]12C',
#  'udp-n-acetylglucosamine': 'CC(=O)N[C@@H]1[C@@H](O)[C@H](O)[C@@H](CO)O[C@@H]1O[P](O)(=O)O[P](O)(=O)OC[C@H]2O[C@H]([C@H](O)[C@@H]2O)N3C=CC(=O)NC3=O',
#  'arabidopsis starch': None,
#  'sterol regulatory element binding protein': None,
#  "8-demethyl-8-formylriboflavin 5'-phosphate": None,
#  'valganciclovir': 'CC(C)[C@H](N)C(=O)OCC(CO)OCn1cnc2C(=O)N=C(N)Nc12',
#  'pro-kallikrein 1': None,
#  '2-hydroxymalonate': 'OC(C([O-])=O)C([O-])=O',
#  'full-length glutamic acid decraboxylase67': None,
#  'heroin': 'CN1CC[C@]23[C@H]4Oc5c(OC(C)=O)ccc(C[C@@H]1[C@@H]2C=C[C@@H]4OC(C)=O)c35',
#  'lipoic acid': 'OC(=O)CCCCC1CCSS1',
#  'icad': None,
#  'organomercurial salts': None,
#  '2-octaprenyl-6-methoxy-1,4-benzoquinone': 'COC1=CC(=O)C=C(C/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC\\C=C(C)\\CCC=C(C)C)C1=O',
#  'pro-integrin-alpha5': None,
#  '4-hydroxy-6-methylpretetramide': 'Cc1c2cccc(O)c2c(O)c3c(O)c4c(O)c(C(N)=O)c(O)c(O)c4cc13',
#  'alpha-(1,4)-glycosidic linked cyclodextrins': None,
#  'plasmin': None,
#  'hydroxylamine': 'NO',
#  'ribulose-1,5-bisphosphate carboxylase/oxygenase small subunit precursor': None,
#  'trimethylamine': 'CN(C)C',
#  'acetyl-6-aminopenicillanic acid': None,
#  '(5s,6s)-6-amino-5-[(1-carboxyethenyl)oxy]cyclohexa-1,3-diene-1-carboxylate': 'N[C@@H]1[C@@H](OC(=C)C(O)=O)C=CC=C1C([O-])=O',
#  'pro-apoai': None,
#  'man5glcnac2': 'CC(=O)N[C@@H](C=O)[C@@H](O[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1NC(C)=O)[C@H](O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](CO[C@H]3O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]3O)O[C@H]4O[C@H](CO)[C@@H](O)[C@H](O[C@H]5O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]5O)[C@@H]4O[C@H]6O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]6O',
#  'skim milk': None,
#  'alpha-l-iduronosyl-(1-&gt;3)-2,5-anhydro-d-talitol 4-sulfate': None,
#  'cyclo(l-leucyl-l-leucyl)': 'CC(C)C[C@@H]1NC(=O)[C@H](CC(C)C)NC1=O',
#  'mevaldyl-coa': 'C[C@@](O)(CC=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  '2-oxoglutarate semialdehyde': 'OC(=O)C(=O)CCC=O',
#  'inositol (1,4,5,6)-tetrakisphosphate': None,
#  'salicylaldehyde': 'Oc1ccccc1C=O',
#  'sphingosylphosphorylcholine': 'CCCCCCCCCCCCC\\C=C\\[C@H](O)[C@H](N)CO[P]([O-])(=O)OCC[N+](C)(C)C',
#  '3-(2,3-dihydroxyphenyl)propionate': 'Oc1cccc(CCC([O-])=O)c1O',
#  'levan': None,
#  'udp-d-galactose': 'OCC1OC(O[P](O)(=O)O[P](O)(=O)OCC2OC(C(O)C2O)N3C=CC(=O)NC3=O)C(O)C(O)C1O',
#  'micx srna': None,
#  'ketoprofen': 'CC(C(O)=O)c1cccc(c1)C(=O)c2ccccc2',
#  'negatively supercoiled dna': None,
#  'olmesartan medoxomil': 'CCCc1nc(c(n1Cc2ccc(cc2)c3ccccc3c4n[nH]nn4)C(=O)OCC5=C(C)OC(=O)O5)C(C)(C)O',
#  '(5z,13e)-(15s)-9alpha,15-dihydroxy-11-oxoprosta-5,13-dienoate': 'CCCCC[C@H](O)/C=C/[C@@H]1[C@@H](C\\C=C/CCCC([O-])=O)[C@@H](O)CC1=O',
#  '(2z, 6e)-farnesyl diphosphate': 'CC(C)=CCCC(/C)=C/CCC(\\C)=C/CO[P]([O-])(=O)O[P]([O-])([O-])=O',
#  'carboxylic aldehyde': None,
#  'udp-n-acetylenolpyruvylglucosamine': 'CC(=O)N[C@H]1[C@H](O[C@H](CO)[C@@H](O)[C@@H]1OC(=C)C(O)=O)O[P](O)(=O)O[P](O)(=O)OC[C@H]2O[C@H]([C@H](O)[C@@H]2O)N3C=CC(=O)NC3=O',
#  '5-(4-hydroxyphenyl) hydantoin': 'Oc1ccc(cc1)C2NC(=O)NC2=O',
#  'pre-elafin': None,
#  '4-aminobenzoylalanine': 'C[C@H](NC(=O)c1ccc(N)cc1)C(O)=O',
#  'hopb1/in': None,
#  '6-phospho-5-dehydro-2-deoxy-d-gluconate': 'OC(CC(O)=O)C(O)C(=O)CO[P](O)(O)=O',
#  'sn-glycero 3-phosphorylethanolamine': None,
#  'calmodulin-l-methionine (r)-sulfoxide': None,
#  'inosine': 'OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)n2cnc3c(O)ncnc23',
#  'lanosterol': 'C[C@H](CCC=C(C)C)[C@H]1CC[C@@]2(C)C3=C(CC[C@]12C)[C@@]4(C)CC[C@H](O)C(C)(C)[C@@H]4CC3',
#  '3-o-alpha-d-mannopyranosyl-d-mannopyranose': 'OCC1OC(OC2C(O)C(O)OC(CO)C2O)C(O)C(O)C1O',
#  'pms-1': None,
#  'fuconate': 'C[C@H](O)[C@@H](O)[C@@H](O)[C@H](O)C([O-])=O',
#  '(+/-)-synephrine': None,
#  'phosphorylated cd3 epsilon': None,
#  'glycero-beta-d-manno-heptose 1-phosphate': None,
#  'fibrin l-arginine': None,
#  '[(r)-3-hydroxybutanoate]n': None,
#  'pentanamide': 'CCCCC(N)=O',
#  'uroporphyrinogen iii': 'OC(=O)CCc1c2Cc3[nH]c(Cc4[nH]c(Cc5[nH]c(Cc([nH]2)c1CC(O)=O)c(CCC(O)=O)c5CC(O)=O)c(CCC(O)=O)c4CC(O)=O)c(CC(O)=O)c3CCC(O)=O',
#  'ceramide': 'CCCCCCCCCCCCC\\C=C\\[C@@H](O)C(CO)NC(=O)CCCCCCC',
#  'an oleoyl-[glycerolipid]': None,
#  'ni(ii)-pyridinium-3,5-bisthiocarboxylate mononucleotide': None,
#  'formononetin': 'COc1ccc(cc1)C2=COc3cc(O)ccc3C2=O',
#  'p-cumic aldehyde': 'CC(C)c1ccc(C=O)cc1',
#  'dihydroxyacetonephosphate': None,
#  'lysophospholipids': None,
#  'citric pectin': None,
#  'angiotensin': 'CC[C@H](C)[C@H](NC(=O)[C@H](Cc1ccc(O)cc1)NC(=O)[C@@H](NC(=O)[C@H](CCCN=C(N)N)NC(=O)[C@@H](N)CC(O)=O)C(C)C)C(=O)N[C@@H](Cc2[nH]cnc2)C(=O)N3CCC[C@H]3C(=O)N[C@@H](Cc4ccccc4)C(O)=O',
#  '4-(dimethylamino)azobenzene': 'CN(C)c1ccc(cc1)N=Nc2ccccc2',
#  'n-acetyl-d-glucosamine 1-phosphate': 'CC(=O)NC1C(O)C(O)C(CO)OC1O[P](O)(O)=O',
#  'methylguanidine': 'CNC(N)=N',
#  'guanine': 'NC1=Nc2nc[nH]c2C(=O)N1',
#  'itp': 'OC1C(O)C(OC1CO[P](O)(=O)O[P](O)(=O)O[P](O)(O)=O)n2cnc3C(=O)N=CNc23',
#  'growth hormone releasing hormone (1-44)': None,
#  'amyloid beta peptide1-42': None,
#  "guanosine 3',5'-cyclic phosphate": 'NC1=NC(=O)c2ncn(C3OC4CO[P](O)(=O)OC4C3O)c2N1',
#  'arc': 'CC(C)CCC[C@H](C)CCC[C@H](C)CCC[C@H](C)CCO',
#  '1-aci-nitro-2-(4-hydroxyphenyl)-ethane': 'Oc1ccc(CC=[N+](O)[O-])cc1',
#  "5'-phosphoribosylformylglycinamide": None,
#  'all-trans-retinyl ester': None,
#  'a dodecanoyl-[acyl-carrier protein]': None,
#  '(4-hydroxyphenyl)pyruvate': 'Oc1ccc(CC(=O)C([O-])=O)cc1',
#  '2-amino-5-chlorophenol': 'Nc1ccc(Cl)cc1O',
#  '1,4-androstadiene-3,17-dione 2 reduced ferredoxin [iron-sulfur] cluster': None,
#  'levans': None,
#  '(2r,3s,4s,5r,6s)-2,3,4,5,6-pentahydroxycyclohexanone': None,
#  'protoporphyrin ix': 'CC\\1C(C=C)C\\2=NC1=C\\C3=NC(=C\\C4=C(CCC(O)=O)C(C)C(=N4)/C=C/5NC(=C2)\\C(=C5C=C)C)/C(=C3C)CCC(O)=O',
#  'propane-1,2-diol-1-phosphate': None,
#  'kanosamine 6-phosphate': 'N[C@@H]1[C@@H](O)C(O)O[C@H](CO[P](O)(O)=O)[C@H]1O',
#  'precursor of transforming growth factor beta': None,
#  'interleukin 12': None,
#  'methylmalonyl-coa': 'CC(C(O)=O)C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  'methyl pyridine-3-carboxylate': 'COC(=O)c1cccnc1',
#  'formamide': 'NC=O',
#  '1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino]imidazole-4-carboxamide': 'NC(=O)c1ncn(C2O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@H]2O)c1N=CNC3O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@H]3O',
#  'pollen cell-wall protein': None,
#  'cholesterol sulfate': 'CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@H](CC[C@]4(C)[C@H]3CC[C@]12C)O[S](O)(=O)=O',
#  '1,1,1-trichloro-2,2-bis-(4-chlorophenyl)ethane': 'Clc1ccc(cc1)C(c2ccc(Cl)cc2)C(Cl)(Cl)Cl',
#  '8-oxo-dgdp': None,
#  'retinyl palmitate': 'CCCCCCCCCCCCCCCC(=O)OC/C=C(C)/C=C/C=C(C)/C=C/C1=C(C)CCCC1(C)C',
#  'gamma-linolenate': 'CCCCC\\C=C/C/C=C\\C\\C=C/CCCCC([O-])=O',
#  '1d-myo-inositol 1,3,4,5-tetrakisphosphate': 'OC1C(O[P](O)(O)=O)C(O)C(O[P](O)(O)=O)C(O[P](O)(O)=O)C1O[P](O)(O)=O',
#  '5-hydroxy-l-tryptophan': 'N[C@@H](Cc1c[nH]c2ccc(O)cc12)C(O)=O',
#  "5'-dtmp": 'CC1=CN([C@H]2C[C@H](O)[C@@H](CO[P](O)(O)=O)O2)C(=O)NC1=O',
#  's-(hydroxymethyl)glutathione': 'N[C@@H](CCC(=O)N[C@@H](CSCO)C(=O)NCC(O)=O)C(O)=O',
#  'n-acetylmuramate 6-phosphate': None,
#  'amyloid-beta': None,
#  '2-(s)hydroxypropyl-com': None,
#  'phosphorylated myosin-light chain kinase': None,
#  'spectrozyme fviia': None,
#  'n-formyl-met-leu-phe': 'CSCC[C@H](NC=O)C(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](Cc1ccccc1)C(O)=O',
#  'p21cip1': None,
#  'arachidonate methyl ester': 'CCCCC/C=C\\C\\C=C/C/C=C\\C\\C=C/CCCC(=O)OC',
#  '(24e)-3alpha,7alpha,12alpha-trihydroxy-5beta-cholest-24-en-26-oyl-coa': 'C[C@H](CC\\C=C(C)\\C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23)[C@H]4CC[C@H]5[C@@H]6[C@H](O)C[C@@H]7C[C@H](O)CC[C@]7(C)[C@H]6C[C@H](O)[C@]45C',
#  'n-phenyl-1-naphthalenamine': 'N(c1ccccc1)c2cccc3ccccc23',
#  'gentiopentaose': None,
#  'amylose': None,
#  'pustulan': None,
#  'n-acetyl-d-glucosamine 6-phosphate': 'CC(=O)N[C@H]1[C@@H](O)O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@@H]1O',
#  'cis-2-chloro-3-methyldienelactone': None,
#  'chymotrypsinogen a': None,
#  '25-hydroxyvitamin d': 'C[C@H](CCCC(C)(C)O)[C@H]1CCC2C(/CCC[C@]12C)=C/C=C3/C[C@H](O)CCC3=C',
#  '1-methylcyclohexene': 'CC1=CCCCC1',
#  '1-hexadecyl-2-acetyl-sn-glycerol-3-phosphocholine': None,
#  'interleukin proil-18': None,
#  'aminoacyl peptide': None,
#  'guanine34 in trna': None,
#  'toluene-2,4-dicarbamic acid dibutyl ester': 'CCCCOC(=O)Nc1ccc(C)c(NC(=O)OCCCC)c1',
#  'peptidyl-l-glutamate': None,
#  '2,3,5,6-tetrachlorohydroquinone': 'Oc1c(Cl)c(Cl)c(O)c(Cl)c1Cl',
#  'manalpha(1-4)manbeta(1-4)man': None,
#  'scc1': None,
#  'adp-beta-d-glycero-d-manno-heptose': None,
#  'propionitrile': 'CCC#N',
#  '4-androstene-3,17-dione': 'C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)CC[C@]34C)[C@@H]1CCC2=O',
#  'pentose': 'OCC(O)C(O)C(O)C=O',
#  'topoisomerase-1': None,
#  'yprpihpa': None,
#  'nitrogen': '[NH2]',
#  'acetone cyanohydrin': 'CC(C)(O)C#N',
#  '2-nitrophenol': 'Oc1ccccc1[N+]([O-])=O',
#  'fasgkrsqig': None,
#  'peroxiredoxin-(s-hydroxy-s-oxocysteine)': None,
#  '[methionine synthase]-methylcob(i)alamin': None,
#  'phosphorylated p38': None,
#  'gonadotropin-releasing hormone': 'CC(C)CC(NC(=O)CNC(=O)C(Cc1ccc(O)cc1)NC(=O)C(CO)NC(=O)C(Cc2c[nH]c3ccccc23)NC(=O)C(Cc4[nH]cnc4)NC(=O)C5CCC(=O)N5)C(=O)NC(CCCN=C(N)N)C(=O)N6CCCC6C(=O)NCC(N)=O',
#  'orcinol': 'Cc1cc(O)cc(O)c1',
#  'palmitoyl-[acyl-carrier protein]': None,
#  '(sumo-1)-histone deacetylase 1 conjugate': None,
#  'ketopantoyl lactone': None,
#  'sumoylated dynamin related protein': None,
#  'nitrite': '[O-]N=O',
#  'protease activated receptor 2': None,
#  'trans-3-hydroxy-l-proline': 'O[C@H]1CCN[C@@H]1C(O)=O',
#  'adiponitrile': 'N#CCCCCC#N',
#  'membrane-bound carcinoembryonic antigen': None,
#  '(8z,11z,14z,17z)-icosa-8,11,14,17-tetraenoyl-coa': 'CC/C=C\\C\\C=C/C/C=C\\C\\C=C/CCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  'ascorbate': 'OC[C@H](O)[C@H]1OC(=O)[C-](O)C1=O',
#  '11alpha-hydroxy-9,15-dioxoprostanoate': 'CCCCCC(=O)CC[C@H]1[C@H](O)CC(=O)[C@@H]1CCCCCCC([O-])=O',
#  'unassembled cytochrome b6f complex': None,
#  'n-3-oxododecanoyl-(s)-homoserine lactone': None,
#  'keratin-l-arginine': None,
#  'caldesmon phosphate': None,
#  'fenbendazole': 'COC(=O)Nc1[nH]c2cc(Sc3ccccc3)ccc2n1',
#  'hexadecanal': 'CCCCCCCCCCCCCCCC=O',
#  "5'-inosinate": 'OC1C(O)C(OC1CO[P](O)(O)=O)n2cnc3C(=O)N=CNc23',
#  'ikappabalpha-ubiquitin': None,
#  '1-butanol': 'CCCCO',
#  "5'-dump": None,
#  'membrane-anchored snare': None,
#  '3,7-dideoxy-d-threo-hepto-2,6-diulosonic acid': 'CC(=O)[C@@H](O)[C@H](O)CC(=O)C(O)=O',
#  '2-hydroxy-3-carboxyadipate': 'OC(C(CCC([O-])=O)C(O)=O)C([O-])=O',
#  'manalpha(1-2)manalpha(1-3)manalpha(1-6)manalpha(1-2)manalpha(1-2)manalpha(1-3)manbeta(1-4)glcnac': None,
#  'phosphorylated nucleoside-diphosphate kinase': None,
#  'gurken protein': None,
#  'beta-isomerized c-telopeptide': None,
#  'c4 complement component': None,
#  'type-ii collagen': None,
#  'pro-interleukin-37': None,
#  '1,5-anhydro-d-fructose': 'OC[C@H]1OCC(=O)[C@@H](O)[C@@H]1O',
#  'amyloid beta40': None,
#  'ompa': 'CN(C)[P](=O)(O[P](=O)(N(C)C)N(C)C)N(C)C',
#  'nde1': None,
#  '1,6-anhydro-murnac-l-ala-gamma-d-glu-m-dap-d-ala-d-ala': None,
#  'prodigiosin': 'CCCCCc1cc([nH]c1C)\\C=C/2NC(/C=C2OC)=C3\\C=CC=N3',
#  'cd44': None,
#  'cbz-gln-gly': None,
#  'kanamycin b': 'NC[C@H]1O[C@H](O[C@@H]2[C@@H](N)C[C@@H](N)[C@H](O[C@H]3O[C@H](CO)[C@@H](O)[C@H](N)[C@H]3O)[C@H]2O)[C@H](N)[C@@H](O)[C@@H]1O',
#  'histone': None,
#  'opn-r': None,
#  '3,4-dihydroxy-9,10-secoandrosta-1,3,5(10)-triene-9,17-dione': 'Cc1ccc(O)c(O)c1CC[C@H]2[C@@H]3CCC(=O)[C@@]3(C)CCC2=O',
#  'fumarate': '[O-]C(=O)/C=C/C([O-])=O',
#  'ribonuclease b': None,
#  'tropomyosin 3': None,
#  'unassembled subunit ii of cytochrome oxidase': None,
#  'methionine-(r)-s-oxide': None,
#  'estronesulfate': None,
#  'beta-d-fructofuranosyl-alpha-d-glucopyranoside': 'OC[C@H]1O[C@H](O[C@]2(CO)O[C@H](CO)[C@@H](O)[C@@H]2O)[C@H](O)[C@@H](O)[C@@H]1O',
#  '4-hydroxy-2-oxoglutarate': 'OC(CC(=O)C([O-])=O)C([O-])=O',
#  'oxidosqualene': 'CC(C)=CCCC(/C)=C/CCC(/C)=C/CC/C=C(C)/CC/C=C(C)/CCC=C(C)C[O-]',
#  'serologically defined colon cancer antigen 3': None,
#  'polysialic acid': None,
#  'glc3man9glcnac2': None,
#  'reduced flavodoxin i': None,
#  'isocitrate': 'OC(C(CC([O-])=O)C([O-])=O)C([O-])=O',
#  '5-methyl-l-kynurenine': None,
#  'ent-sandaracopimaradien-3beta-ol': None,
#  '4-(ethylamino)-2-hydroxy-6-(isopropylamino)-1,3,5-triazine': 'CCNc1nc(O)nc(NC(C)C)n1',
#  'cdpribitol': 'NC1=NC(=O)N(C=C1)[C@@H]2O[C@H](CO[P](O)(=O)O[P](O)(=O)OC[C@@H](O)[C@@H](O)[C@@H](O)CO)[C@@H](O)[C@H]2O',
#  'stearoyl-acyl-carrier protein': None,
#  'n-succinyl ll-diaminopimelic acid': None,
#  '4-caffeoyl-coa': None,
#  'glycerol 1-phosphate': 'OCC(O)CO[P](O)(O)=O',
#  'maleylpyruvate': 'OC(=O)\\C=C/C(=O)CC(=O)C(O)=O',
#  'fertilization envelope': None,
#  'eif5a-nepsilon-(4-aminobutyl)lysine': None,
#  'alpha-l-fucopyranose': 'C[C@@H]1O[C@@H](O)[C@@H](O)[C@H](O)[C@@H]1O',
#  'alpha-santonin': 'C[C@H]1[C@@H]2CC[C@@]3(C)C=CC(=O)C(=C3[C@H]2OC1=O)C',
#  'manalpha(1-6)glcnac': None,
#  'trans-2,3-dehydroacyl-[acyl-carrier protein]': None,
#  '5-formyluracil-mismatched single-stranded dna': None,
#  '3beta-hydroxy-4alpha-methyl-5alpha-cholest-7-ene-4beta-carboxylate': None,
#  'dithiane': 'C1CCSSC1',
#  '11-deoxy-cortisol': None,
#  '13-deoxycarminomycin': 'CC[C@@]1(O)C[C@H](O[C@H]2C[C@H](N)[C@H](O)[C@H](C)O2)c3c(O)c4C(=O)c5c(O)cccc5C(=O)c4c(O)c3C1',
#  'beta-casein': None,
#  '9-(phenylcarbonyl)-2,3,6,7-tetrahydro-1h,5h,11h-pyrano[2,3-f]pyrido[3,2,1-ij]quinolin-11-one': 'O=C1Oc2c3CCCN4CCCc(cc2C(=C1)C(=O)c5ccccc5)c34',
#  'bicyclo[3.2.0]hept-2-en-6-one': 'O=C1CC2C=CCC12',
#  '1-acyl-2-palmitoyl-[glycerolipid]': None,
#  'endostatin': None,
#  '4-hydroxybenzoyl-adenylate': None,
#  'hemin': '[Cl-].[Fe+3].Cc1c2[n-]c(cc3[n-]c(cc4nc(cc5nc(c2)c(C)c5C=C)c(C)c4C=C)c(C)c3CCC(O)=O)c1CCC(O)=O',
#  'trehalose-6-phosphate': 'OC[C@H]1O[C@@H](OC2O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@H](O)[C@H]2O)[C@H](O)[C@@H](O)[C@@H]1O',
#  'ac-rrll-7-amido-4-methylcoumarin': None,
#  'cytokeratin 8': None,
#  "5-(4-acetoxybut-1-ynyl)-2,2'-bithiophene": 'CC(=O)OCCC#Cc1sc(cc1)c2sccc2',
#  'outer membrane protein f': None,
#  'alpha-spectrin': None,
#  '1d-myo-inositol 1,3,4,5,6-pentakisphosphate': 'OC1[C@H](O[P](O)(O)=O)[C@@H](O[P](O)(O)=O)C(O[P](O)(O)=O)[C@@H](O[P](O)(O)=O)[C@@H]1O[P](O)(O)=O',
#  'cytochrome c oxidase 4 precursor protein': None,
#  '3-oxosteroid': 'CC12CCCC1C3CCC4CC(=O)CCC4(C)C3CC2',
#  'bornane-2,6-dione': 'CC1(C)C2CC(=O)C1(C)C(=O)C2',
#  'alpha2-antiplasmin': None,
#  'cysteine': 'N[C@@H](CS)C(O)=O',
#  'salutaridine': 'COc1ccc2C[C@H]3N(C)CC[C@@]4(C=C(OC)C(=O)C=C34)c2c1O',
#  'aspartic acid': 'N[C@@H](CC(O)=O)C(O)=O',
#  '3-hydroxybutanoyl-coa': 'CC(O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  '3,5-diiodo-l-tyrosine': 'N[C@@H](Cc1cc(I)c(O)c(I)c1)C(O)=O',
#  '6-o-beta-d-glucopyranosyl-d-glucose': 'OC[C@H]1O[C@@H](OC[C@H]2OC(O)[C@H](O)[C@@H](O)[C@@H]2O)[C@H](O)[C@@H](O)[C@@H]1O',
#  '3-oxoadipate': '[O-]C(=O)CCC(=O)CC([O-])=O',
#  '5,6-dihydrothymine': 'CC1CNC(=O)NC1=O',
#  'heparosan-n-sulfate d-glucuronate': None,
#  'aminoacyl-trna': None,
#  '2-nitroacetanilide': '[O-][N+](=O)CC(=O)Nc1ccccc1',
#  '1-oxo-d-chiro-inositol': None,
#  'lactotrehalose': None,
#  '2,5-anhydro-3-o-alpha-l-idopyranuronosyl-d-mannitol': None,
#  'notch1': None,
#  'polyadenylate': None,
#  '17alpha-hydroxypregnenolone': 'CC(=O)[C@@]1(O)CC[C@H]2[C@@H]3CC=C4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'potato starch': None,
#  'cyclo(l-tyrosyl-l-tyrosyl)': 'Oc1ccc(C[C@@H]2NC(=O)[C@H](Cc3ccc(O)cc3)NC2=O)cc1',
#  '(z)-9-tetradecenoic acid': 'CCCC\\C=C/CCCCCCCC(O)=O',
#  'human immunoglobulin a1': None,
#  'map2k': None,
#  'asp-trnaasn': None,
#  'precursor of glucose-binding protein': None,
#  'integrin': 'COc1cc2[nH]c(C)c(CCN3CCN(CC3)c4ccccc4)c2cc1OC',
#  'n2-acetyl-l-ornithine': 'CC(=O)NC(CCCN)C(O)=O',
#  'mrna': None,
#  'hexanoyl-coa': 'CCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  'pectate': 'O[C@H]1O[C@@H]([C@H](OC2O[C@@H]([C@H](OC3O[C@@H]([C@H](O)[C@H](O)[C@H]3O)C(O)=O)[C@H](O)[C@H]2O)C(O)=O)[C@H](O)[C@H]1O)C(O)=O',
#  '2-o-alpha-d-mannotriose': None,
#  'pipecolate': '[O-]C(=O)C1CCCCN1',
#  'alcohol': 'CCO',
#  'proglucagon': None,
#  'proform prostasin': None,
#  'podocalyxin-like protein 1': None,
#  'diphosphate': '[O-][P]([O-])(=O)O[P]([O-])([O-])=O',
#  "biotinyl-5'-amp": 'Nc1ncnc2n(cnc12)[C@@H]3O[C@H](CO[P](O)(=O)OC(=O)CCCC[C@@H]4SCC5NC(=O)NC45)[C@@H](O)[C@H]3O',
#  'methyl aklanonate': None,
#  'ras': 'C#CCN[C@@H]1CCc2ccccc12',
#  '(z)-2-methylaconitate': None,
#  'protein spitz': None,
#  'galnac-alpha-(1-3)-gal-[fuc-alpha-(1-2)]': None,
#  'cofilin i': None,
#  '3-(4-hydroxyphenyl)pyruvate': 'Oc1ccc(CC(=O)C([O-])=O)cc1',
#  '3beta,12alpha-dihydroxy-5beta-cholan-24-oic acid': 'C[C@H](CCC(O)=O)[C@H]1CC[C@H]2[C@@H]3CC[C@@H]4C[C@@H](O)CC[C@]4(C)[C@H]3C[C@H](O)[C@]12C',
#  '4-methyl-3-hydroanthranilic acid methyl ester': None,
#  '2-amino-1-hydroxyoctadecane-3-one': 'CCCCCCCCCCCCCCCC(=O)C(N)CO',
#  'alpha-d-man-(1-2)-alpha-d-man-(1-2)-alpha-d-man-(1-3)-[alpha-d-man-(1-6)-[alpha-d-man-(1-2)-alpha-d-man-(1-3)]-alpha-d-man-(1-6)]-beta-d-man-(1-4)-beta-d-glcnac': None,
#  '10-formyltetrahydropteroylpentaglutamate': None,
#  'fructose-bisphosphate aldolase a': None,
#  '1-(2-chlorophenyl)ethanol': 'CC(O)c1ccccc1Cl',
#  '24-methylenecholesterol': 'CC(C)C(=C)CC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'divinyl protochlorophyllide a': None,
#  'aprotinin': None,
#  'kinetensin': 'CC[C@H](C)[C@H](N)C(=O)N[C@@H](C)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N[C@@H](CCCN=C(N)N)C(=O)N[C@@H](Cc1[nH]cnc1)C(=O)N2CCC[C@H]2C(=O)N[C@@H](Cc3ccc(O)cc3)C(=O)N[C@@H](Cc4ccccc4)C(=O)N[C@@H](CC(C)C)C(O)=O',
#  'n-palmitoyl ethanolamine': None,
#  '[iia-fpr diphosphoryl transfer protein]-npi-phospho-l-histidine': None,
#  'aromatic acids': None,
#  'thiacetazone': 'CC(=O)Nc1ccc(cc1)/C=N/NC(N)=S',
#  '3-oxoadipate enol-lactone': 'OC(=O)CC1=CCC(=O)O1',
#  '4-methyldibenzothiophene': 'Cc1cccc2c1sc3ccccc23',
#  'n-acetyl-lysine-alpha-tubulin': None,
#  'gal-beta-(1-4)-glcnac-[fuc-alpha-(1-4)]-beta-(1-3)-gal-beta-(1-4)-glc': None,
#  'primary fluorescent chlorophyll catabolite': None,
#  'phosphorylated prz1': None,
#  '1-alkyl-sn-glycero-3-phosphocholine': None,
#  'amyloid beta-precursor protein': None,
#  'fatty acyl-[acyl carrier protein]': None,
#  '[(4-d-ala)-(2-glcnac)-rib-ol-p]n-[gro-p]m-mannac-glcnac-pp-peptidoglycan': None,
#  'beta-d-fructofuranosyl 6-o-phosphono-alpha-d-glucopyranoside': 'OC[C@H]1O[C@@](CO)(O[C@H]2O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@H](O)[C@H]2O)[C@@H](O)[C@@H]1O',
#  'lacytm2 protein': None,
#  'platelet activating factor': 'CCCCCCCCCCCCCCCCOC[C@H](CO[P]([O-])(=O)OCC[N+](C)(C)C)OC(C)=O',
#  'starvation proteins': None,
#  '(9s,13s)-12-oxo-phytodienoic acid': None,
#  'forssman glycolipid': None,
#  'sumoylated krab-associated protein 1': None,
#  'beta2 subunit of voltage-gated sodium channel': None,
#  'cd x glutathione s2/cytoplasm': None,
#  'dihydroxyacetone 3-phosphate': 'OCC(=O)CO[P](O)(O)=O',
#  'iodoacetic acid': 'OC(=O)CI',
#  'cycloeucalenol': 'CC(C)C(=C)CC[C@@H](C)[C@H]1CC[C@@]2(C)[C@@H]3CC[C@H]4[C@H](C)[C@@H](O)CC[C@@]45C[C@@]35CC[C@]12C',
#  'mouse cxcl-2': None,
#  'gamma-tubulin': None,
#  'phenol': 'Oc1ccccc1',
#  'menadione': 'CC1=CC(=O)c2ccccc2C1=O',
#  'naphthalene-cis-1,2-dihydrodiol': None,
#  '(5s)-5-amino-3-oxohexanoate': 'C[C@H](N)CC(=O)CC([O-])=O',
#  'arsenate': '[O-][As]([O-])([O-])=O',
#  '1-pyrroline-5-carboxylate': '[O-]C(=O)C1CCC=N1',
#  'peptidyl-trnalys': None,
#  'leucin-rich repeats and immunoglobulin-like domains protein 2': None,
#  'bovine kappa-casein': None,
#  'cdpglycerol': 'NC1=NC(=O)N(C=C1)[C@@H]2O[C@H](CO[P](O)(=O)O[P](O)(=O)OCC(O)CO)[C@@H](O)[C@H]2O',
#  '(sumo-1)-homeodomain-interacting protein kinase 2 conjugate': None,
#  'z-gly-pro-leu-gly-pro': 'CC(C)C[C@H](NC(=O)[C@@H]1CCCN1C(=O)CNC(=O)OCc2ccccc2)C(=O)NCC(=O)N3CCC[C@H]3C(O)=O',
#  '[heat stable phosphocarrier protein hpr]-npi-phospho-l-histidine': None,
#  '4-methyl-muconolactone': 'CC1=CCOC(=O)C=C1',
#  'cystathionine': 'N[C@@H](CCSC[C@H](N)C(O)=O)C(O)=O',
#  'lambda-carrageenan': 'OC[C@H]1O[C@@H](O[C@@H]2[C@H](O)[C@@H](O[S]([O-])(=O)=O)[C@H](O[C@@H]2CO[S]([O-])(=O)=O)O[C@H]3[C@@H](O)[C@@H](CO)O[C@@H](O[C@@H]4[C@H](O)[C@@H](O[S]([O-])(=O)=O)[C@@H](O)O[C@@H]4CO[S]([O-])(=O)=O)[C@@H]3O[S]([O-])(=O)=O)[C@H](O[S]([O-])(=O)=O)[C@@H](O)[C@H]1O',
#  'cefamandole': 'Cn1nnnc1SCC2=C(N3[C@H](SC2)[C@H](NC(=O)[C@H](O)c4ccccc4)C3=O)C(O)=O',
#  'galactosylceramide': 'CCCCCCCCCCCCNCC(O)C(O)C(OC1OC(CO)C(O)C(O)C1O)C(O)CO',
#  'isoquinoline': 'c1ccc2cnccc2c1',
#  'coenzyme b-coenzyme m disulfide': None,
#  "luteolin-4'-beta-glucopyranoside": None,
#  'geranyl diphosphate': 'CC(C)=CCCC(/C)=C/CO[P]([O-])(=O)O[P]([O-])([O-])=O',
#  'benzaldehyde': 'O=Cc1ccccc1',
#  'quinate': 'OC1CC(O)(CC(O)C1O)C(O)=O',
#  'dabcyl-bp-1 peptide-edans': None,
#  'gamma-cyclodextrin': 'CC(=O)OC[C@H]1O[C@H](OC(C)=O)[C@H](OC(C)=O)[C@@H](OC(C)=O)[C@@H]1O[C@@H]2O[C@H](COC(C)=O)[C@@H](OC(C)=O)[C@H](OC(C)=O)[C@H]2OC(C)=O',
#  "3,5'-diiodo-l-thyronine": 'N[C@@H](Cc1ccc(Oc2ccc(O)c(I)c2)c(I)c1)C(O)=O',
#  '2-hydroxypropyl-1-phosphonate': None,
#  'ripk1': None,
#  'receptor tyrosine kinase c-kit': None,
#  'glucuronic acid': 'O[C@@H](C=O)[C@@H](O)[C@H](O)[C@H](O)C(O)=O',
#  'low density lipoprotein receptor': None,
#  'mandelonitrile-beta-d-glucopyranoside': None,
#  'beta-n-acetylgalactosaminylated oligosaccharides': None,
#  '5alpha-androstane-3,17-dione': 'C[C@]12CCC(=O)C[C@@H]1CC[C@@H]3[C@@H]2CC[C@@]4(C)[C@H]3CCC4=O',
#  '1,2-hexanediol': 'CCCCC(O)CO',
#  'malto-triose': None,
#  '(z)-4-hydroxyphenylacetaldehyde oxime': 'O\\N=C/Cc1ccc(O)cc1',
#  'm-tyrosine': 'NC([C@H](O)c1ccccc1)C(O)=O',
#  '3alpha-hydroxy-7,12-diketo-5beta-cholanoic acid': 'C[C@H](CCC(O)=O)[C@H]1CC[C@H]2[C@H]3[C@H](CC(=O)[C@]12C)[C@@]4(C)CC[C@@H](O)C[C@H]4CC3=O',
#  '2-mercaptoethanesulfonate': '[O-][S](=O)(=O)CCS',
#  'n-acetylglucosamine 6-phosphate': 'CC(=O)N[C@@H](C=O)[C@@H](O)[C@H](O)[C@H](O)CO[P](O)(O)=O',
#  'sedoheptulose 1,7-bisphosphate': 'OC(CO[P](O)(O)=O)C(O)C(O)C(O)C(=O)CO[P](O)(O)=O',
#  'dolichyl diphosphate': 'CC\\C(C)=C\\CCCC(C)CCO[P](O)(=O)O[P](O)(O)=O',
#  'poly(adp-ribose)n': None,
#  'tobacco mosaic virus rna': None,
#  '2-imino-3-(7-chloroindol-3-yl)propanoate': '[O-]C(=O)C(=N)Cc1c[nH]c2c(Cl)cccc12',
#  'pro-oxytocin/neurophysin': None,
#  'beta-myrcene': 'CC(C)=CCCC(=C)C=C',
#  'dextran t2000': None,
#  'pheophytin a': 'CCc1c(C)c2[nH]c1cc3nc4c([C@@H](C(=O)OC)C(=O)c4c3C)c5nc(cc6[nH]c(c2)c(C=C)c6C)[C@@H](C)[C@@H]5CCC(=O)OC/C=C(C)/CCC[C@H](C)CCC[C@H](C)CCCC(C)C',
#  'paxillin': None,
#  'lactose-6-phosphate': None,
#  'nr2b subunit of nmda receptor': None,
#  'deoxyinosine-containing dna': None,
#  'wheat flour arabinoxylan': None,
#  'dctp': 'NC1=NC(=O)N(C=C1)C2CC(O)C(CO[P](O)(=O)O[P](O)(=O)O[P](O)(O)=O)O2',
#  'n-acetyl-d-glucosamine-6-phosphate': 'CC(=O)NC1C(O)OC(CO[P](O)(O)=O)C(O)C1O',
#  'purine base': None,
#  'n-amidino-l-aspartic acid': 'NC(N)=N[C@@H](CC(O)=O)C(O)=O',
#  'methyl vanillate': 'COC(=O)c1ccc(O)c(OC)c1',
#  'delta5-3beta-hydroxysteroid': None,
#  'human proinsulin': None,
#  'gluv8': None,
#  '5-d/l-glutamyl-phenylhydrazine': None,
#  'fuc-alpha-(1-2)-xyl': None,
#  '3-bromobenzoyl-coa': 'CC(C)(CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23)[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)c4cccc(Br)c4',
#  '1-o-hexadecyl-sn-glycero-3-phosphocholine': 'CCCCCCCCCCCCCCCCOC[C@@H](O)CO[P]([O-])(=O)OCC[N+](C)(C)C',
#  '4-amino-4-deoxy-alpha-l-arabinopyranosyl di-trans,poly-cis-undecaprenyl phosphate': None,
#  '2,4,6-trichlorophenol': 'Oc1c(Cl)cc(Cl)cc1Cl',
#  'diphosphoinositol polyphosphate': None,
#  '23s rrna uridine2457': None,
#  '2-butyne-1,4-diol': 'OCC#CCO',
#  '5-hydroxymethyl-uracil-mismatched single-stranded dna': None,
#  'macrophage inflammatory protein-1 (mip-1) alpha': None,
#  'typhasterol': 'CC(C)[C@H](C)[C@@H](O)[C@H](O)[C@@H](C)[C@H]1CCC2[C@@H]3CC(=O)[C@H]4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'adp-ribose-arginine': None,
#  'sinapoyl-coa': 'COc1cc(/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]2O[C@H]([C@H](O)[C@@H]2O[P](O)(O)=O)n3cnc4c(N)ncnc34)cc(OC)c1O',
#  'phylloquinone': 'CC(C)CCCC(C)CCCC(C)CCC/C(C)=C/CC1=C(C)C(=O)c2ccccc2C1=O',
#  '9s,13r-12-oxo-phytodienoic acid': None,
#  'histone h3-n6,n6,n6-trimethyl-l-lysine36': None,
#  '1,1,1-trichloro-2,2-bis(4-chlorophenyl)ethane': 'Clc1ccc(cc1)C(c2ccc(Cl)cc2)C(Cl)(Cl)Cl',
#  'myo-inositol 1,4,5-trisphosphate': 'O[C@H]1[C@@H](O)[C@H](O[P](O)(O)=O)[C@@H](O[P](O)(O)=O)[C@H](O)[C@H]1O[P](O)(O)=O',
#  'n2o': '[N-]=[N+]=O',
#  'cholest-7-en-3beta-ol': 'CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2C3=CCC4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'octane': 'CCCCCCCC',
#  'sinigrin': '[K+].OC[C@H]1O[C@@H](SC(/CC=C)=N/O[S]([O-])(=O)=O)[C@H](O)[C@@H](O)[C@@H]1O',
#  'acrolein': 'C=CC=O',
#  'fibrillarin': None,
#  '2-hydroxypropylphosphonate': 'CC(O)C[P]([O-])([O-])=O',
#  '2-phenylethylamine': 'NCCc1ccccc1',
#  'phenylalanyl-trna': None,
#  'single stranded dna': None,
#  'polysaccharides': None,
#  'p23 rna': None,
#  'melanopsin': None,
#  'nitrated dna': None,
#  'gp120 oligosaccharides': None,
#  '2-aminomuconate': 'N\\C(=C/C=C/C([O-])=O)C([O-])=O',
#  'acetonitrile': 'CC#N',
#  'glucagon-like peptide 2': None,
#  'complement component c4': None,
#  'alpha1-antitrypsin': None,
#  'notch 1': None,
#  '3-(imidazol-5-yl)lactate': 'OC(Cc1[nH]cnc1)C([O-])=O',
#  'alpha-d-glucose': 'OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O',
#  'prorenin': None,
#  'platelet-derived growth factor b precursor': None,
#  'eukaryotic initiation factor': None,
#  '(-)-kaurene': None,
#  '(2s)-4-hydroxyphenylglycine': None,
#  '[protein hpr]-npi-phospho-l-histidine': None,
#  'thiamine diphosphate': 'Cc1ncc(C[n+]2csc(CCO[P](O)(=O)O[P](O)([O-])=O)c2C)c(N)n1',
#  'rna-dna heteroduplex': None,
#  '(2s)-flavanone': 'O=C1C[C@H](Oc2ccccc12)c3ccccc3',
#  '2,3-diketo-4-deoxy-epi-inositol': None,
#  'histidinol': 'N[C@H](CO)Cc1c[nH]cn1',
#  'gliadins': None,
#  'a 4-hydroxy-3-polyprenylbenzoate': None,
#  '4-hydroxy-4-methyl-2-oxoglutarate': 'CC(O)(CC(=O)C([O-])=O)C([O-])=O',
#  'dna containing a cytosine:adenine mismatch': None,
#  '4-acetamidophenol': 'CC(=O)Nc1ccc(O)cc1',
#  'orf 1a polyprotein': None,
#  'folate': 'NC1=Nc2ncc(CNc3ccc(cc3)C(=O)N[C@@H](CCC([O-])=O)C(O)=O)nc2C(=O)N1',
#  'adenine in double-stranded rna': None,
#  'folic acid': 'NC1=Nc2ncc(CNc3ccc(cc3)C(=O)N[C@@H](CCC(O)=O)C(O)=O)nc2C(=O)N1',
#  'chey': None,
#  'veratrate': 'COc1ccc(cc1OC)C([O-])=O',
#  'podj protein': None,
#  'big-endothelin-1': None,
#  's-allyl-cys sulfoxide': None,
#  '5-phospho-alpha-d-ribose 1-diphosphate': 'O[C@H]1[C@@H](O)[C@H](O[C@@H]1CO[P](O)(O)=O)O[P](O)(=O)O[P](O)(O)=O',
#  'chlorophyll a/b': None,
#  'pro-endothelial monocyte-activating polypeptide ii': None,
#  '(3r)-3-hydroxydecanoyl-[acyl-carrier protein]': None,
#  'low-density lipoprotein receptor-related protein 11': None,
#  'glycogen': 'OC[C@H]1O[C@H](OC[C@H]2O[C@H](O[C@H]3[C@H](O)[C@@H](O)[C@@H](O)O[C@@H]3CO)[C@H](O)[C@@H](O)[C@@H]2O[C@H]4O[C@H](CO)[C@@H](O)[C@H](O)[C@H]4O)[C@H](O)[C@@H](O)[C@@H]1O',
#  '(4-coumaroyl)acetyl-coa': None,
#  '(24r,241r)-fucosterol epoxide': None,
#  "5'-dimp": None,
#  'pyrin': None,
#  'dicatechol': None,
#  'adhesion molecule cd3246': None,
#  '5-amino-6-ribitylamino-2,4(1h,3h)-pyrimidinedione': 'NC1=C(NCC(O)C(O)C(O)CO)NC(=O)NC1=O',
#  '3-(4-hydroxyphenyl)lactate': 'OC(Cc1ccc(O)cc1)C([O-])=O',
#  'feruloyl polysaccharide': None,
#  'c20:1-ceramide': None,
#  'albumin': None,
#  'proenkephalin': None,
#  'trnapro precursor': None,
#  'pheophorbide a': 'CCc1c(C)c2[nH]c1cc3nc4c([C@@H](C(=O)OC)C(=O)c4c3C)c5nc(cc6[nH]c(c2)c(C=C)c6C)[C@@H](C)[C@@H]5CCC(O)=O',
#  '4-deoxy-beta-d-gluc-4-enuronosyl-(1,4)-n-acetyl-d-galactosamine 6-sulfate': None,
#  '5-phospho-beta-d-ribosylamine': 'N[C@@H]1O[C@H](CO[P](O)(O)=O)[C@@H](O)[C@H]1O',
#  'barley beta-glucan': None,
#  'beta-d-galactose': 'OC[C@H]1O[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O',
#  'p-trnahis': None,
#  '2-deoxyribose 5-phosphate': 'O[C@H](CO[P](O)(O)=O)[C@@H](O)CC=O',
#  'phenylhydrazine': 'NNc1ccccc1',
#  'bid': 'C/C=C/C(=O)C[C@H]1CC[C@H](C)[C@H](CC(=O)NC[C@H](O)[C@H](C)C(=O)NCCC[C@H]2O[C@@]3(CCC[C@@H](CC[C@H](C)\\C=C(C)\\[C@H](C)O)O3)CC[C@@H]2C)O1',
#  'polyvinyl alcohol': 'OC=C',
#  'phosphatidylserine/out': None,
#  'pimeloyl-coa': 'CC(C)(CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23)[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)CCCCCC(O)=O',
#  'sweet sorghum starch': None,
#  'codeine': 'COc1ccc2C[C@@H]3[C@@H]4C=C[C@H](O)[C@@H]5Oc1c2[C@]45CCN3C',
#  '(+)-sabinene': None,
#  '3-deoxygluconosone': None,
#  '2-dehydro-3-deoxy-d-arabinonate': 'OC[C@@H](O)CC(=O)C([O-])=O',
#  'pyridoxamine': 'Cc1ncc(CO)c(CN)c1O',
#  'alpha-neoendorphin': None,
#  "5'-imp": 'OC1C(O)C(OC1CO[P](O)(O)=O)n2cnc3C(=O)N=CNc23',
#  'vomilenine': None,
#  'histidine': 'N[C@@H](Cc1c[nH]cn1)C(O)=O',
#  'hypoxia-inducible factor-l-proline': None,
#  'ethionine': 'CCSCC[C@H](N)C(O)=O',
#  'alpha-d-glucose 1-phosphate': 'OC[C@H]1O[C@H](O[P](O)(O)=O)[C@H](O)[C@@H](O)[C@@H]1O',
#  'transmembrane collagen xvii': None,
#  'tripalmitin': 'CCCCCCCCCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC',
#  '(3s)-3-amino-3-(3-chloro-4-hydroxyphenyl)propanoyl-[peptidyl-carrier protein sgcc2]': None,
#  'nitrobenzene': '[O-][N+](=O)c1ccccc1',
#  '4-amino-5-oxopentanoate': 'NC(CCC([O-])=O)C=O',
#  'n8-glutathionylspermidine': None,
#  'n-carbobenzoxy-l-glutaminylglycine': None,
#  'oleuropein': 'COC(=O)C1=CO[C@@H](O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)C(=C\\C)/[C@@H]1CC(=O)OCCc3ccc(O)c(O)c3',
#  'insulin-like growth factor binding protein-4': None,
#  'n-formylanthranilic acid': 'OC(=O)c1ccccc1NC=O',
#  '2-hydroxycaprylate': 'CCCCCCC(O)C([O-])=O',
#  'ganglioside gm1': 'CCCCCCCCCCCCCCCCCC(=O)NC(CO[C@@H]1O[C@H](CO)[C@@H](O[C@@H]2O[C@H](CO)[C@H](O[C@@H]3O[C@H](CO)[C@H](O)[C@H](O[C@@H]4O[C@H](CO)[C@H](O)[C@H](O)[C@H]4O)[C@H]3NC(C)=O)[C@H](OCC(O)C(O)[C@@H]5O[C@@](O)(C[C@H](O)[C@H]5NC(C)=O)C(O)=O)[C@H]2O)[C@H](O)[C@H]1O)C(O)\\C=C\\CCCCCCCCCCCCC',
#  'glutamic acid': 'N[C@@H](CCC(O)=O)C(O)=O',
#  '2,4-dichloroaniline': 'Nc1ccc(Cl)cc1Cl',
#  'acetylated peptidoglycan': None,
#  'protein kinase czeta': None,
#  'undecaprenyl diphosphate': 'CC(C)=CCC/C(C)=C/CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CO[P](O)(=O)O[P](O)(O)=O',
#  '(2e,4z)-2-hydroxy-6-oxonona-2,4-dienedioate': 'O\\C(=C\\C=C/C(=O)CCC([O-])=O)C([O-])=O',
#  'imipramine': 'CN(C)CCCN1c2ccccc2CCc3ccccc13',
#  'spoivfa': None,
#  'pentalenolactone f': None,
#  'plastoquinol': 'CC(C)=CCC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC/C(C)=C/CC/C(C)=C/Cc1cc(O)c(C)c(C)c1O',
#  'phaseolin': 'CC1(C)Oc2ccc3[C@@H]4COc5cc(O)ccc5[C@@H]4Oc3c2C=C1',
#  'utrophin': None,
#  'wiskott-aldrich syndrome protein': None,
#  "p1,p3-bis(5'-adenosyl)triphosphate": 'Nc1ncnc2n(cnc12)C3OC(CO[P](O)(=O)O[P](O)(=O)O[P](O)(=O)OCC4OC(C(O)C4O)n5cnc6c(N)ncnc56)C(O)C3O',
#  'glucosedependent insulinotropic polypeptide': None,
#  '[eif5a-precursor]-lysine': None,
#  'complement componentc3': None,
#  '3-sulfolactate': 'OC(C[S](O)(=O)=O)C([O-])=O',
#  '5beta-cholestane-3alpha,7alpha-diol': 'CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3[C@H](O)C[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'z-phe-arg-nhme': None,
#  'dystrophin': None,
#  'laminaribiose': 'OC[C@H]1O[C@@H](O[C@@H]2[C@@H](O)C(O)O[C@H](CO)[C@H]2O)[C@H](O)[C@@H](O)[C@@H]1O',
#  'pyrogallol': 'Oc1cccc(O)c1O',
#  'haloperidol': 'OC1(CCN(CCCC(=O)c2ccc(F)cc2)CC1)c3ccc(Cl)cc3',
#  '4,4-dimethyl-zymosterol': None,
#  'sigma32': None,
#  'recombinant procaspase-3': None,
#  "1'-hydroxy-gamma-carotene": 'CC(/CCCC(C)(C)O)=C\\C=C\\C(C)=C\\C=C\\C(C)=C\\C=C\\C=C(C)\\C=C\\C=C(C)\\C=C\\C1=C(C)CCCC1(C)C',
#  'type ii procollagen': None,
#  'pea glutathione reductase': None,
#  'kda fragment of photosystem ii d1 protein': None,
#  'ptrnatyr': None,
#  '7-hydroxy-methotrexate': None,
#  'fgf-2': None,
#  'a sulfoquinovosyl diacylglyceride': None,
#  'gamma-l-glutamyl-l-cysteinyl-glycine': 'N[C@@H](CCC(=O)N[C@@H](CS)C(=O)NCC(O)=O)C(O)=O',
#  'formate': '[O-]C=O',
#  'alpha-(1-6)-mannobiose': None,
#  '4,6-dimethyldibenzothiophene': 'Cc1cccc2c1sc3c(C)cccc23',
#  'caspase-8': None,
#  'sumoylated foxc2': None,
#  'flab2 protein': None,
#  'ahnak nucleoprotein': None,
#  'n1-methyladenine in ssdna': None,
#  '5-formiminotetrahydrofolate': 'NC1=NC2=C(N(C=N)C(CNc3ccc(cc3)C(=O)N[C@@H](CCC([O-])=O)C(O)=O)CN2)C(=O)N1',
#  'pre-[epidermal growth factor]': None,
#  'cd27 protein': None,
#  'fumitremorgin b': 'COc1ccc2c(c1)n(CC=C(C)C)c3[C@H](C=C(C)C)N4C(=O)[C@@H]5CCCN5C(=O)[C@]4(O)[C@@H](O)c23',
#  'protein d2': None,
#  'beta-chloro-d-alanine': 'N[C@H](CCl)C(O)=O',
#  '1-o-sinapoyl-beta-d-glucose': 'COc1cc(\\C=C\\C(=O)O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)cc(OC)c1O',
#  'polygalacturonan': None,
#  'cis-(homo)2aconitate': None,
#  'uracil16 in trna': None,
#  'proform matriptase': None,
#  '(5-l-glutamyl)-peptide': None,
#  'pregn-4-en-3,20-dione': 'CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'n-(3-oxooctanoyl)-l-homoserine lactone': 'CCCCCC(=O)CC(=O)N[C@H]1CCOC1=O',
#  'taxa-4(20),11(12)-dien-5alpha-yl acetate': 'CC(=O)O[C@H]1CC[C@@]2(C)CCC3=C(C)CC[C@@H](C[C@@H]2C1=C)C3(C)C',
#  'capsular polysaccharides': None,
#  'limonene': 'CC(=C)C1CCC(=CC1)C',
#  'pro-matrix metalloproteinase-2': None,
#  'interleukin-6 receptor beta chain': None,
#  '131-hydroxy-magnesium-protoporphyrin ix 13-monomethyl ester': None,
#  'glutathione/cytoplasm': None,
#  'caspase 9': None,
#  '2-methylmalonyl-coa': 'CC(C(O)=O)C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23',
#  'ovalbumin': None,
#  'aromatic amines': None,
#  'hydroxybenzyl alcohol': 'OC(O)c1ccccc1',
#  'o-nitrophenyl alpha-d-galactopyranoside': 'OC[C@H]1O[C@H](Oc2ccccc2[N+]([O-])=O)[C@H](O)[C@@H](O)[C@H]1O',
#  'sphinganine': 'CCCCCCCCCCCCCCC[C@@H](O)[C@@H](N)CO',
#  'fba protein': None,
#  'isoniazid': 'NNC(=O)c1ccncc1',
#  'pro-collagen type i': None,
#  'cab2r protein precursor': None,
#  'senecionine': 'C/C=C1/C[C@@H](C)[C@@](C)(O)C(=O)OCC2=CCN3CC[C@@H](OC1=O)[C@@H]23',
#  'ribose 1-phosphate': 'OC[C@H]1O[C@H](O[P](O)(O)=O)[C@H](O)[C@@H]1O',
#  '13,14-dihydro-15-ketoprostaglandin f2alpha': 'CCCCCC(=O)CC[C@H]1[C@H](O)C[C@H](O)[C@@H]1C\\C=C/CCCC(O)=O',
#  '(-)-yatein': None,
#  'progesterone': 'CC(=O)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'organo-tin compounds': None,
#  '(13s)-hydroperoxy-(9z,11e)-octadecadienoic acid': None,
#  'nornicotine': 'C1CNC(C1)c2cccnc2',
#  'trihydroxycoprostanoyl-coa': None,
#  'glucagon-like peptide 1': None,
#  '4-methylcyclohexan-1-one': 'CC1CCC(=O)CC1',
#  'ubiquinol-10': 'COC1=C(OC)C(O)C(=C(C)C1O)C\\C=C(C)\\CC\\C=C(C)\\CC/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC/C=C(C)/CC\\C=C(C)\\CCC=C(C)C',
#  'butanoate': 'CCCC([O-])=O',
#  'acetylpyruvate': 'CC(=O)CC(=O)C([O-])=O',
#  'terephthalate': '[O-]C(=O)c1ccc(cc1)C([O-])=O',
#  'a 2-oxo acid': None,
#  'cyclohexane-1,3-dione': 'O=C1CCCC(=O)C1',
#  'slr': None,
#  'rsea protein': None,
#  'lysosomal associated membrane protein 2': None,
#  'methyl gallate': 'COC(=O)c1cc(O)c(O)c(O)c1',
#  'docosenol': 'CCCCCCCCCCCCCCCCCCCCC=CO',
#  'panose': 'OC[C@H]1O[C@H](OCC2O[C@H](O[C@H]3[C@H](O)[C@@H](O)C(O)O[C@@H]3CO)[C@H](O)[C@@H](O)[C@@H]2O)[C@H](O)[C@@H](O)[C@@H]1O',
#  'calciol': 'CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2\\C(CCC[C@]12C)=C\\C=C3\\C[C@@H](O)CCC3=C',
#  'double-stranded dna': None,
#  'phosphorylated pro-apoptotic bcl-2-associated x protein': None,
#  'histone h2a ending on val114': None,
#  '3,4,5-trihydroxy-l-phenylalanine': 'N[C@@H](Cc1cc(O)c(O)c(O)c1)C(O)=O',
#  'plasminogen': None,
#  'poly(adp-ribose) polymerase': None,
#  'o-succinylbenzoyl-coa': 'CC(C)(CO[P](O)(=O)O[P](O)(=O)OCC1OC(C(O)C1O[P](O)(O)=O)n2cnc3c(N)ncnc23)C(O)C(=O)NCCC(=O)NCCSC(=O)c4ccccc4C(=O)CCC(O)=O',
#  'herpesvirus associated ubiquitin-specific protease': None,
#  '4-hydroxyestradiol': 'C[C@]12CC[C@H]3[C@@H](CCc4c(O)c(O)ccc34)[C@@H]1CC[C@@H]2O',
#  '3-hydroxytetradecanoyl-[acyl-carrier protein]': None,
#  'long-chain alcohol': None,
#  'protein-nomega-(adp-d-ribosyl)-l-arginine': None,
#  'isobutyronitrile': 'CC(C)C#N',
#  'octaprenyl diphosphate': 'CC(C)=CCC/C(C)=C/CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CC\\C(C)=C\\CO[P](O)(=O)O[P](O)(O)=O',
#  'galactosylsphingoside': None,
#  'myo-inositol-1,2,3,4,5,6-hexakisphosphate': None,
#  'cupric-histidine[side 1]': None,
#  '5-hydroxymethyluracil-mismatched single-stranded dna': None,
#  'deoxyinosine-containing deoxyoligonucleotide': None,
#  '1-hydroxy-1,2,4-butanetricarboxylate': 'OC(C(CCC([O-])=O)C([O-])=O)C([O-])=O',
#  'n-methyl-d-aspartate': 'CN[C@H](CC([O-])=O)C([O-])=O',
#  '1,8-diazacyclotetradecane-2,9-dione': 'O=C1CCCCCNC(=O)CCCCCN1',
#  'kinetin': 'C(Nc1ncnc2nc[nH]c12)c3occc3',
#  "2'-phospho-[ligated trna]": None,
#  'enoyl-acp': None,
#  'leu-phe': None,
#  '(+)-copalyl-diphosphate': None,
#  '(5z,13e)-(15s)-11alpha,15-dihydroxy-9-oxoprost-5,13-dienoate': 'CCCCC[C@H](O)/C=C/[C@H]1[C@H](O)CC(=O)[C@@H]1C\\C=C/CCCC([O-])=O',
#  'aggrecan': None,
#  '6-biopterin': 'CC(O)C(O)c1cnc2NC(=NC(=O)c2n1)N',
#  'human antiprotease alpha2-antiplasmin': None,
#  'vesicular integral-membrane protein vip36': None,
#  'arabinose': 'OC[C@@H](O)[C@@H](O)[C@H](O)C=O',
#  'poly(gamma-glutamic acid)': None,
#  "n-[(r)-4'-phosphopantothenoyl]-l-cysteine": 'CC(C)(CO[P](O)(O)=O)[C@@H](O)C(=O)NCCC(=O)N[C@@H](CS)C(O)=O',
#  'methionine (r)-sulfoxide': None,
#  'galactosyl-n-acylsphingosine': None,
#  'coa-disulfide': 'CC(C)(CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23)C(O)C(=O)NCCC(=O)NCCSSCCNC(=O)CCNC(=O)C(O)C(C)(C)CO[P](O)(=O)O[P](O)(=O)OC[C@H]4O[C@H]([C@H](O)[C@@H]4O[P](O)(O)=O)n5cnc6c(N)ncnc56',
#  '4-hydroxybenzoyl-coa': 'CC(C)(CO[P](O)(=O)O[P](O)(=O)OC[C@H]1O[C@H]([C@H](O)[C@@H]1O[P](O)(O)=O)n2cnc3c(N)ncnc23)[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)c4ccc(O)cc4',
#  'manalpha(1-3)glcnac': None,
#  '5alpha-androstane-3alpha,17beta-diol': 'C[C@]12CC[C@H]3[C@@H](CC[C@H]4C[C@H](O)CC[C@]34C)[C@@H]1CC[C@@H]2O',
#  'pro-thyrotropin-releasing hormone': None,
#  'glycerophosphoinositol': 'OCC(O)CO[P](O)(=O)OC1[C@@H](O)[C@H](O)C(O)[C@H](O)[C@@H]1O',
#  'cholest-4-en-3-one': 'CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4(C)[C@H]3CC[C@]12C',
#  'ethanolamine': 'NCCO',
#  'mitochondrial antiviral signaling protein': None,
#  '2-hydroxy-4-methylthiobutanoic acid': 'CCCC(O)C(O)=S',
#  '[e2 ubiquitin-conjugating enzyme ubch7]-s-ubiquitinyl-l-cysteine': None,
#  'gdp-d-mannuronate': 'NC1=NC(=O)c2ncn(C3OC(CO[P](O)(=O)O[P](O)(=O)OC4OC(C(O)C(O)C4O)C(O)=O)C(O)C3O)c2N1',
#  'major histocompatibility complex class i polypeptide-related sequence b': None,
#  'gep100': None,
#  'viral nucleocapsid protein of transmissible gastroenteritis coronovirus': None,
#  '1-phosphatidyl-1d-myo-inositol 1,3,4,5-tetrakisphosphate': None,
#  'poly(3-hydroxyoctanoate)': None,
#  'oxidized adrenodoxin': None,
#  '9-cis-zeaxanthin': None,
#  ...}

# %% [markdown]
# Lets' see how many substrates we are talking about for all of BRENDA

# %%
all_substrates = set([])
for ec in get_all_ec():
    all_substrates.update(get_substrates(ec))
    
print('Unique substrates in BRENDA: %s' % len(all_substrates))
# Out:
# Unique substrates in BRENDA: 8461

# %% [markdown]
# Now convert these and save to file for every 100 completed ones

# %%
import cirpy


data = load_data()

counter = 0
for name in all_substrates:
    counter += 1
    
    if name not in data.keys():
        data[name] = cirpy.resolve(name, 'smiles')
        
    if counter % 100 == 0:
        print(counter)
        save_data(data)
save_data(data)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400

# %%
data = load_data()

sum([s is not None for s in data.values()])
# Out:
# 3641
